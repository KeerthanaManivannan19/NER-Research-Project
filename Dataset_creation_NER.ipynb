# %%
# !pip install contractions
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.9/113.9 kB 9.5 MB/s eta 0:00:00
# ...

# %%
import nltk
nltk.download('punkt_tab')  # Correct resource name
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
import nltk
import pandas as pd
import contractions
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk import pos_tag

# Downloads (run only once)
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')

# Input text
input_text = """
On July 1, 2025, Virat Kohli smashed 105 runs in a cricket match at Eden Gardens.

Rohit Sharma hit six boundaries on July 2, 2025, during a thrilling cricket game at Wankhede Stadium.

Steve Smith stabilized the innings with 82 runs on July 3, 2025, in a test cricket match at SCG.

On July 4, 2025, David Warner guided Australia with a steady 78 in a cricket game at Adelaide Oval.

Rishabh Pant’s aggressive 95 lit up the cricket crowd on July 5, 2025, at Chinnaswamy Stadium.

On July 6, 2025, Jasprit Bumrah bowled a devastating opening spell in a cricket match at Perth Stadium.

KL Rahul hit a match-winning half-century on July 7, 2025, in a cricket T20 at DY Patil Stadium.

Mohammed Shami claimed four wickets on July 8, 2025, in a cricket match at Narendra Modi Stadium.

On July 9, 2025, Shubman Gill scored a stylish 92 in a cricket ODI at Rajiv Gandhi Stadium.

Ben Stokes delivered a superb all-round performance on July 10, 2025, in a cricket test at Lord’s.

On July 11, 2025, Joe Root batted patiently for 88 runs in a close cricket match at Headingley.

Hardik Pandya sealed victory with a last-over six on July 12, 2025, in a cricket T20 at Eden Gardens.

Babar Azam guided Pakistan’s chase on July 13, 2025, in a cricket match at Gaddafi Stadium.

On July 14, 2025, Ravindra Jadeja picked up four wickets in a spinning track cricket match at The Oval.

Mitchell Starc claimed a five-wicket haul on July 15, 2025, during a cricket test at MCG.

On July 1, 2025, Quinton de Kock scored a quick 70 in a cricket ODI at SuperSport Park.

Kane Williamson stood firm with a 99 not out on July 2, 2025, in a test cricket match at Basin Reserve.

Glenn Maxwell added late fireworks with a 40-ball 70 on July 3, 2025, in a cricket game at SCG.

On July 4, 2025, Axar Patel spun a web around the batters in a cricket match at Arun Jaitley Stadium.

Pat Cummins turned the game with his pace on July 5, 2025, in a tight cricket match at Gabba.

Moeen Ali’s crucial spell helped England win the cricket match on July 6, 2025, at Old Trafford.

On July 7, 2025, Trent Boult bowled a deadly final over in a cricket game at Hagley Oval.

Marnus Labuschagne batted through the innings on July 8, 2025, in a test cricket match at Brisbane.

Lungi Ngidi’s early breakthroughs rattled the top order on July 9, 2025, in a cricket match at Newlands.

On July 10, 2025, Shreyas Iyer contributed a fluent 78 in a cricket match at Eden Gardens.

Ravichandran Ashwin baffled the batters with spin on July 11, 2025, in a cricket game at M. A. Chidambaram Stadium.

On July 12, 2025, Ishan Kishan hit five sixes in a fast-paced cricket game at Barabati Stadium.

Shaheen Afridi bowled a fiery spell on July 13, 2025, in a cricket match at Rawalpindi Cricket Stadium.

Ferran Torres impressed with a solo run on July 14, 2025, in a football match at Nou Camp.

On July 15, 2025, Hakim Ziyech’s assist sealed the win in a football game at Stamford Bridge.

Richarlison scored a late equalizer for Brazil on July 3, 2025, in a football friendly at Maracanã.

Lautaro Martínez converted a penalty on July 4, 2025, in Argentina’s football match at La Bombonera.

Alphonso Davies made a crucial clearance on July 5, 2025, in a football game at Allianz Arena.

Christian Pulisic scored a decisive goal for the USA on July 6, 2025, in a football match at Soldier Field.

Heung-min Son’s goal stunned Italy on July 7, 2025, in a football match at San Siro.

On July 8, 2025, Edinson Cavani celebrated his 100th goal in a football match at Estadio Centenario.

Andre Onana kept a clean sheet on July 9, 2025, during a football match at Old Trafford.

Wilfried Zaha netted twice on July 10, 2025, in a football match at Selhurst Park.

Takefusa Kubo’s winning goal lifted Japan on July 11, 2025, in a football game at Tokyo Stadium.

Mehdi Taremi stunned the defense with a chip goal on July 12, 2025, in a football match at Azadi Stadium.
"""

# Expand contractions and clean
input_text = input_text.replace('-', ' ')
expanded_words = [contractions.fix(word) for word in input_text.split()]
expanded_text1 = ' '.join(expanded_words)

# Initialize
lemmatizer = WordNetLemmatizer()

# Helper function to convert POS tags
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# Tokenize sentences
sentences = sent_tokenize(expanded_text1)

# Prepare storage
sentence_numbers = []
words = []
lemmas = []

sentence_number = 0

# Process each sentence
for sentence in sentences:
    sentence_number += 1
    tokens = word_tokenize(sentence)
    tokens = [word for word in tokens if word.isalnum()]  # Remove punctuation
    tagged_tokens = pos_tag(tokens)

    for word, tag in tagged_tokens:
        sentence_numbers.append(sentence_number)
        words.append(word)
        pos = get_wordnet_pos(tag)
        lemma = lemmatizer.lemmatize(word, pos=pos)
        lemmas.append(lemma)

# Create DataFrame
df = pd.DataFrame({
    'Sentence Number': sentence_numbers,
    'Word': words,
    'Lemmatization': lemmas
})

print(df.head(20))  # Preview first 20 rows
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#     Sentence Number     Word Lemmatization
# 0                 1       On            On
# 1                 1     July          July
# 2                 1        1             1
# 3                 1     2025          2025
# 4                 1    Virat         Virat
# 5                 1    Kohli         Kohli
# 6                 1  smashed         smash
# 7                 1      105           105
# 8                 1     runs           run
# ...

# %%
(df.head(20))
# Out:
#     Sentence Number      Word Lemmatization
# 0                 1        On            On
# 1                 1      July          July
# 2                 1         1             1
# 3                 1      2025          2025
# 4                 1     Virat         Virat
# 5                 1     Kohli         Kohli
# 6                 1   powered         power
# 7                 1     India         India
# 8                 1      with          with
# 9                 1         a             a
# 10                1  majestic      majestic
# 11                1       ton           ton
# 12                1        in            in
# 13                1         a             a
# 14                1   cricket       cricket
# 15                1     match         match
# 16                1        at            at
# 17                1  Wankhede      Wankhede
# 18                1   Stadium       Stadium
# 19                2     David         David

# %%
df.to_csv('content\dataset_Sample_sports_5.csv', index=False)
